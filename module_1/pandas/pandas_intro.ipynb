# %% [markdown]
# # Intro to Pandas

# %%
import pandas as pd

# %% [markdown]
# # Sacramento pandas
#
# 1. Load the csv
# 2. Run some transformations
#
#     - Capitalize 'city'
#     - convert to int:
#         - 'zip'
#         - 'beds'
#         - 'baths'
#         - 'sq__ft'
#         - 'price'
#     - convert to float:
#         - 'latitude'
#         - 'longitude'
#     - rename 'sq__ft' to 'sq_ft'
#     - convert 'sale_date' into format: "YYYY-MM-DD"

# %%
df = pd.read_csv("Sacramentorealestatetransactions.csv")

# %%
df.head(5)
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
type(df['street'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# I'm a Series!

# %%
df['street'].head(5)
# Out:
# 0        3526 HIGH ST
# 1         51 OMAHA CT
# 2      2796 BRANCH ST
# 3    2805 JANETTE WAY
# 4     6001 MCMAHON DR
# Name: street, dtype: object

# %%
type(df[['street']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['street']].head(5)
# Out:
#              street
# 0      3526 HIGH ST
# 1       51 OMAHA CT
# 2    2796 BRANCH ST
# 3  2805 JANETTE WAY
# 4   6001 MCMAHON DR

# %%
# Let me create a copy that I can mess up
df_clean = df.copy()

# %% [markdown]
# ## 1: Replace "__" in 'sq__ft' with "_"

# %%
df_clean.columns
# Out:
# Index(['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
#        'sale_date', 'price', 'latitude', 'longitude'],
#       dtype='object')

# %%
list(df_clean.columns)
# Out:
# ['street',
#  'city',
#  'zip',
#  'state',
#  'beds',
#  'baths',
#  'sq__ft',
#  'type',
#  'sale_date',
#  'price',
#  'latitude',
#  'longitude']

# %%
type(df_clean.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
for i in df_clean.columns:
    print(i)
# Out:
# street
# city
# zip
# state
# beds
# baths
# sq__ft
# type
# sale_date
# price
# latitude
# longitude

# %%
df_clean.columns = [col.replace("__","_") for col in list(df_clean.columns)]

# %%
df_clean.head(5)
# Out:
#              street        city    zip state  beds  baths  sq_ft         type  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1    836  Residential
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1   1167  Residential
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1    796  Residential
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1    852  Residential
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1    797  Residential
#
#                       sale_date  price   latitude   longitude
# 0  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %% [markdown]
# ## 2. Capitalize the 'city' column

# %%
df_clean['city'] = df_clean['city'].str.capitalize()

# %%
df_clean.head()
# Out:
#              street        city    zip state  beds  baths  sq_ft         type  \
# 0      3526 HIGH ST  Sacramento  95838    CA     2      1    836  Residential
# 1       51 OMAHA CT  Sacramento  95823    CA     3      1   1167  Residential
# 2    2796 BRANCH ST  Sacramento  95815    CA     2      1    796  Residential
# 3  2805 JANETTE WAY  Sacramento  95815    CA     2      1    852  Residential
# 4   6001 MCMAHON DR  Sacramento  95824    CA     2      1    797  Residential
#
#                       sale_date  price   latitude   longitude
# 0  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %% [markdown]
# ## 3. Convert column types

# %%
df_clean.dtypes
# Out:
# street        object
# city          object
# zip            int64
# state         object
# beds           int64
# baths          int64
# sq_ft          int64
# type          object
# sale_date     object
# price          int64
# latitude     float64
# longitude    float64
# dtype: object

# %% [markdown]
# Pandas already inferred the right types when using pd.read_csv().
#
#
# How would I change it if I wanted to?

# %%
df_clean['latitude'].astype(int)
# Out:
# 0      38
# 1      38
# 2      38
# 3      38
# 4      38
#        ..
# 980    38
# 981    38
# 982    38
# 983    38
# 984    38
# Name: latitude, Length: 985, dtype: int64

# %% [markdown]
# ## 4. Convert weird date string into 'YYYY-MM-DD' representation

# %%
df_clean["sale_date"] = pd.to_datetime(df_clean["sale_date"], infer_datetime_format=True)

# %%
df_clean.to_pickle("clean_sacramento.pkl")
df_clean.to_csv("clean_sacramento.csv")

# %% [markdown]
# ## General pandas stuff, plus a little bit of numpy

# %%
import numpy as np

# %%
np.random.random_sample((5,))
# Out:
# array([0.96508561, 0.52115325, 0.02012193, 0.79319021, 0.10121299])

# %%
np.random.random_sample((3, 2))
# Out:
# array([[0.86798315, 0.63401669],
#        [0.04835692, 0.13852062],
#        [0.48915355, 0.63238242]])

# %%
col_names = ["banana_density", "banana_mass", "apple_density", "apple_mass"]
df = pd.DataFrame(np.random.random_sample((10, 4)), columns=col_names)

# %%
df
# Out:
#    banana_density  banana_mass  apple_density  apple_mass
# 0        0.115217     0.579536       0.570065    0.639582
# 1        0.801474     0.369596       0.885262    0.581397
# 2        0.099973     0.292971       0.697579    0.659084
# 3        0.985773     0.802603       0.650774    0.380358
# 4        0.218095     0.622017       0.729822    0.676884
# 5        0.376950     0.361918       0.438711    0.856053
# 6        0.103614     0.347819       0.627770    0.815891
# 7        0.920128     0.868313       0.353560    0.216111
# 8        0.059206     0.468220       0.017453    0.891227
# 9        0.669779     0.696239       0.270674    0.996573

# %% [markdown]
# ## Subestting
#
# ### 1. Columns

# %%
apples = ["apple_density", "apple_mass", "apple_mass"]
df[apples]
# Out:
#    apple_density  apple_mass  apple_mass
# 0       0.570065    0.639582    0.639582
# 1       0.885262    0.581397    0.581397
# 2       0.697579    0.659084    0.659084
# 3       0.650774    0.380358    0.380358
# 4       0.729822    0.676884    0.676884
# 5       0.438711    0.856053    0.856053
# 6       0.627770    0.815891    0.815891
# 7       0.353560    0.216111    0.216111
# 8       0.017453    0.891227    0.891227
# 9       0.270674    0.996573    0.996573

# %%
df[["apple_density", "apple_mass", "apple_mass"]]
# Out:
#    apple_density  apple_mass  apple_mass
# 0       0.570065    0.639582    0.639582
# 1       0.885262    0.581397    0.581397
# 2       0.697579    0.659084    0.659084
# 3       0.650774    0.380358    0.380358
# 4       0.729822    0.676884    0.676884
# 5       0.438711    0.856053    0.856053
# 6       0.627770    0.815891    0.815891
# 7       0.353560    0.216111    0.216111
# 8       0.017453    0.891227    0.891227
# 9       0.270674    0.996573    0.996573

# %%
# Sorting

df.sort_values("banana_density", ascending=False)
# Out:
#    banana_density  banana_mass  apple_density  apple_mass
# 3        0.985773     0.802603       0.650774    0.380358
# 7        0.920128     0.868313       0.353560    0.216111
# 1        0.801474     0.369596       0.885262    0.581397
# 9        0.669779     0.696239       0.270674    0.996573
# 5        0.376950     0.361918       0.438711    0.856053
# 4        0.218095     0.622017       0.729822    0.676884
# 0        0.115217     0.579536       0.570065    0.639582
# 6        0.103614     0.347819       0.627770    0.815891
# 2        0.099973     0.292971       0.697579    0.659084
# 8        0.059206     0.468220       0.017453    0.891227

# %%
some_new_column = np.random.random_sample((10,))
some_new_column
# Out:
# array([0.50452397, 0.07582705, 0.44090607, 0.58965361, 0.26251021,
#        0.73751552, 0.18216337, 0.76155813, 0.65674264, 0.83288635])

# %%
# Adding a column
df["mango_mass"] = some_new_column

# %%
pd.Series(some_new_column)
# Out:
# 0    0.504524
# 1    0.075827
# 2    0.440906
# 3    0.589654
# 4    0.262510
# 5    0.737516
# 6    0.182163
# 7    0.761558
# 8    0.656743
# 9    0.832886
# dtype: float64

# %%
df
# Out:
#    banana_density  banana_mass  apple_density  apple_mass  mango_mass
# 0        0.115217     0.579536       0.570065    0.639582    0.504524
# 1        0.801474     0.369596       0.885262    0.581397    0.075827
# 2        0.099973     0.292971       0.697579    0.659084    0.440906
# 3        0.985773     0.802603       0.650774    0.380358    0.589654
# 4        0.218095     0.622017       0.729822    0.676884    0.262510
# 5        0.376950     0.361918       0.438711    0.856053    0.737516
# 6        0.103614     0.347819       0.627770    0.815891    0.182163
# 7        0.920128     0.868313       0.353560    0.216111    0.761558
# 8        0.059206     0.468220       0.017453    0.891227    0.656743
# 9        0.669779     0.696239       0.270674    0.996573    0.832886

# %%
df_new = df.sort_values("banana_density", ascending=False)

# %%
df_new["mango_mass"] = pd.Series(some_new_column)

# %%
df_new
# Out:
#    banana_density  banana_mass  apple_density  apple_mass  mango_mass
# 3        0.985773     0.802603       0.650774    0.380358    0.589654
# 7        0.920128     0.868313       0.353560    0.216111    0.761558
# 1        0.801474     0.369596       0.885262    0.581397    0.075827
# 9        0.669779     0.696239       0.270674    0.996573    0.832886
# 5        0.376950     0.361918       0.438711    0.856053    0.737516
# 4        0.218095     0.622017       0.729822    0.676884    0.262510
# 0        0.115217     0.579536       0.570065    0.639582    0.504524
# 6        0.103614     0.347819       0.627770    0.815891    0.182163
# 2        0.099973     0.292971       0.697579    0.659084    0.440906
# 8        0.059206     0.468220       0.017453    0.891227    0.656743

# %%
df_new.reset_index(drop=True)
# Out:
#    banana_density  banana_mass  apple_density  apple_mass  mango_mass
# 0        0.985773     0.802603       0.650774    0.380358    0.589654
# 1        0.920128     0.868313       0.353560    0.216111    0.761558
# 2        0.801474     0.369596       0.885262    0.581397    0.075827
# 3        0.669779     0.696239       0.270674    0.996573    0.832886
# 4        0.376950     0.361918       0.438711    0.856053    0.737516
# 5        0.218095     0.622017       0.729822    0.676884    0.262510
# 6        0.115217     0.579536       0.570065    0.639582    0.504524
# 7        0.103614     0.347819       0.627770    0.815891    0.182163
# 8        0.099973     0.292971       0.697579    0.659084    0.440906
# 9        0.059206     0.468220       0.017453    0.891227    0.656743

# %%
df_new = df_new.reset_index(drop=True)

# %%
df_new
# Out:
#    banana_density  banana_mass  apple_density  apple_mass  mango_mass
# 0        0.985773     0.802603       0.650774    0.380358    0.589654
# 1        0.920128     0.868313       0.353560    0.216111    0.761558
# 2        0.801474     0.369596       0.885262    0.581397    0.075827
# 3        0.669779     0.696239       0.270674    0.996573    0.832886
# 4        0.376950     0.361918       0.438711    0.856053    0.737516
# 5        0.218095     0.622017       0.729822    0.676884    0.262510
# 6        0.115217     0.579536       0.570065    0.639582    0.504524
# 7        0.103614     0.347819       0.627770    0.815891    0.182163
# 8        0.099973     0.292971       0.697579    0.659084    0.440906
# 9        0.059206     0.468220       0.017453    0.891227    0.656743

# %%
df_super_new = (df_new
                .sort_values("mango_mass")
                .reset_index(drop=True))

# %%
df_super_new
# Out:
#    banana_density  banana_mass  apple_density  apple_mass  mango_mass
# 0        0.801474     0.369596       0.885262    0.581397    0.075827
# 1        0.103614     0.347819       0.627770    0.815891    0.182163
# 2        0.218095     0.622017       0.729822    0.676884    0.262510
# 3        0.099973     0.292971       0.697579    0.659084    0.440906
# 4        0.115217     0.579536       0.570065    0.639582    0.504524
# 5        0.985773     0.802603       0.650774    0.380358    0.589654
# 6        0.059206     0.468220       0.017453    0.891227    0.656743
# 7        0.376950     0.361918       0.438711    0.856053    0.737516
# 8        0.920128     0.868313       0.353560    0.216111    0.761558
# 9        0.669779     0.696239       0.270674    0.996573    0.832886

# %%
df_super_new["banana_mass"] < 0.5
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8    False
# 9    False
# Name: banana_mass, dtype: bool

# %%
df_super_new[df_super_new["banana_mass"] < 0.5]
# Out:
#    banana_density  banana_mass  apple_density  apple_mass  mango_mass
# 0        0.115217     0.579536       0.570065    0.639582    0.504524
# 1        0.801474     0.369596       0.885262    0.581397    0.075827
# 3        0.985773     0.802603       0.650774    0.380358    0.589654
# 6        0.103614     0.347819       0.627770    0.815891    0.182163
# 7        0.920128     0.868313       0.353560    0.216111    0.761558

# %%
df_super_new[[True, False, False, True, False, False, True, False, False, True]]
# Out:
#    banana_density  banana_mass  apple_density  apple_mass  mango_mass
# 0        0.115217     0.579536       0.570065    0.639582    0.504524
# 3        0.985773     0.802603       0.650774    0.380358    0.589654
# 6        0.103614     0.347819       0.627770    0.815891    0.182163
# 9        0.669779     0.696239       0.270674    0.996573    0.832886

# %%
df_super_new[(df_super_new["mango_mass"] > .1) & (df_super_new["apple_density"] < .9)][["banana_mass", "apple_density"]]
# Out:
#    banana_mass  apple_density
# 1     0.347819       0.627770
# 2     0.622017       0.729822
# 3     0.292971       0.697579
# 4     0.579536       0.570065
# 5     0.802603       0.650774
# 6     0.468220       0.017453
# 7     0.361918       0.438711
# 8     0.868313       0.353560
# 9     0.696239       0.270674
